# %%
# !pip install transformers faiss-gpu torch accelerate sentencepiece nltk pypdf2 pymupdf
from IPython.display import clear_output
clear_output()

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModel
import requests
from bs4 import BeautifulSoup
import faiss
import nltk
import numpy as np

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
llm = pipeline(model="databricks/dolly-v2-3b",
               torch_dtype=torch.bfloat16,
               trust_remote_code=True,
               device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/819 [00:00<?, ?B/s]
# instruct_pipeline.py:   0%|          | 0.00/9.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-3b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/5.68G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from PyPDF2 import PdfReader

reader = PdfReader("/content/sample-story.pdf")
content = "".join([page.extract_text() for page in reader.pages])
print(content)
# Out:
# The Secret of Elysium Woods
#
# It all started with a missing dog. Benny, a sprightly golden retriever with a tendency to wander off, had disappeared from the yard again. For
# twelve-year-old Sarah, this was becoming a frustrating routine. Her parents had warned her countless times to keep the gate locked, but
# somehow Benny always found a way to slip away. This time, however, Benny hadn’t returned by evening. The sun had long since set, casting a
# deep blue shadow over the small town of Elysium, and Sarah felt a growing knot of worry in her stomach.
#
# "He's probably just chasing squirrels in the woods," her older brother Jack had said, though he didn't seem too concerned. Jack, at sixteen, had a
# way of brushing off everything like it didn’t matter.
#
# But for Sarah, it did matter. Benny wasn’t just a dog—he was her best friend, her only companion during the long, lazy summer days when
# school was out. So, despite her parents' protests, Sarah grabbed a flashlight, pulled on her hoodie, and headed out to look for him.
#
# The woods that bordered the edge of town, known as Elysium Woods, had always intrigued Sarah. They were dense and dark, filled with
# towering trees that seemed to stretch endlessly toward the sky. It was said that no one really knew how deep the woods went, or what lay
# hidden beyond the first few miles. Local legends spoke of strange occurrences—unexplained lights at night, whispers carried on the wind, and
# figures that seemed to vanish the moment you turned to look. None of the adults ever took those stories seriously, of course, but kids like Sarah
# had always wondered.
#
# As she approached the tree line, the familiar rustling of leaves and the soft hooting of owls greeted her. She called out Benny’s name, her voice
# shaking a little in the stillness of the night. No response, except for the wind stirring the branches.
#
# Sarah ventured deeper into the woods, the beam of her flashlight cutting through the darkness in jittery patterns. She kept calling for Benny, the
# sound of her own voice the only thing keeping her grounded in the eerie quiet. After what felt like an hour of walking, she spotted something in
# the distance—a faint, flickering light, like a candle struggling to stay lit.
#  Her heart leaped. *Maybe someone found Benny*, she thought. She quickened her pace, weaving through the trees and over fallen logs, her
# sneakers crunching softly against the undergrowth. But as she got closer, she realized the light wasn’t coming from a flashlight or a lantern. It
# was... floating.
#
# Sarah stopped in her tracks, her breath catching in her throat. The glowing orb hovered about three feet off the ground, pulsing with a soft,
# warm glow. It reminded her of a firefly, only much larger and... stranger. She stood frozen, staring at it, when suddenly it darted off deeper into
# the woods, as if beckoning her to follow.
#
# Against her better judgment, Sarah ran after it, the light of her flashlight bobbing wildly as she hurried through the trees. The glowing orb moved
# faster, darting left and right, leading her down paths she had never ventured before. She lost track of how long she had been running—ten
# minutes, twenty minutes, maybe more. The trees grew thicker, and the air seemed heavier, cooler.
#
# Just as she thought she had lost the orb, it stopped. The glowing light hovered in place for a moment before slowly dimming, as if its energy
# was fading. Sarah slowed her steps, approaching cautiously. Then, she saw it—an ancient, stone archway hidden amongst the trees, covered in
# moss and vines. The orb flickered one last time before disappearing altogether.
#
# Sarah stood before the archway, her heart pounding. It looked like something out of a fairy tale. Intricate carvings lined the stone, worn with age
# but still recognizable. Strange symbols she had never seen before were etched into the surface, and there was something written across the top
# in an ancient script she couldn’t decipher.
#
# She hesitated, glancing around to make sure no one else was there. The woods were still, almost unnaturally so. Swallowing her fear, Sarah
# stepped through the archway.
#
# On the other side, the world felt different—quieter, almost dreamlike. The trees here were even older, their trunks wide and gnarled, their
# branches twisting toward the sky like the arms of ancient giants. The air was thick with the scent of earth and rain, though no storm had
# passed. And there, in the middle of a clearing, sat Benny.
# He was lying in the grass, calm and content, as if nothing was out of the ordinary. Sarah’s heart surged with relief. “Benny!” she cried, rushing
# over to him. But as she knelt down to pet him, she noticed something strange. His fur shimmered faintly, as if dusted with a soft, golden light.
#
# Before she could react, she heard a voice—a deep, melodic sound that seemed to come from everywhere and nowhere at once.
#
# "You have found the gateway."
#
# Sarah jumped to her feet, spinning around. There was no one there. The woods were empty, yet the voice lingered, echoing in her ears.
#
# “The gateway to what?” she asked, her voice shaking.
#
# “To the place where the lost things go. Few have ever found it, but those who do, never return the same.”
#
# Sarah’s mind raced. What did that mean? She glanced back at Benny, who was now sitting up, looking at her with those same gentle eyes, but
# something was different. His gaze seemed wiser, more knowing, as if he understood something she didn’t.
#
# “Why is Benny here?” she asked, trying to steady her voice. “What is this place?”
#
# The voice was silent for a moment before it answered. “This is Elysium, the heart of the woods, where the boundary between worlds is thin.
# Your dog has wandered into the in-between, a place of secrets and forgotten things. But now that you have crossed the threshold, you are part
# of the secret, too.”
#  Sarah’s breath caught in her throat. Part of the secret? She hadn’t asked for this. All she wanted was to find her dog and go home. But
# something told her that leaving wouldn’t be so simple.
#
# As the wind stirred the leaves around her, Sarah realized she had stumbled into something far bigger than she could have ever imagined. The
# woods held a secret—a secret that was now hers to uncover.
#
# The voice spoke one last time, quieter now, almost a whisper. “Be careful, child. Once you’ve seen the other side, there is no going back.”
#
# And with that, the forest fell silent once more, leaving Sarah alone with Benny and the weight of a mystery she didn’t know how to solve.

# %%
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-mpnet-base-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-mpnet-base-v2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
def chunk_content_by_sentence(content):
    return sent_tokenize(content)

content_chunks = chunk_content_by_sentence(content)
print(f"Number of content chunks (sentences): {len(content_chunks)}")
# Out:
# Number of content chunks (sentences): 81

# %%
chunk_embeddings = []
for chunk in content_chunks:
    inputs = tokenizer(chunk, return_tensors='pt', max_length=512, truncation=True)
    with torch.no_grad():
        embedding = model(**inputs).last_hidden_state.mean(dim=1).numpy()
    chunk_embeddings.append(embedding)

embeddings_np = np.vstack(chunk_embeddings)
print(f"Shape of embeddings: {embeddings_np.shape}")
# Out:
# Shape of embeddings: (81, 768)

# %%
dimension = embeddings_np.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings_np)
print("Number of vectors in the FAISS index:", index.ntotal)
# Out:
# Number of vectors in the FAISS index: 81

# %%
def generate_rag_response(query, model, tokenizer, index, content_chunks):

    query_inputs = tokenizer(query, return_tensors='pt')
    with torch.no_grad():
        query_embedding = model(**query_inputs).last_hidden_state.mean(dim=1).detach().numpy()
    k = 2
    distances, indices = index.search(query_embedding, k)
    relevant_contexts = [content_chunks[i] for i in indices[0]]
    combined_context = " ".join(relevant_contexts)

    input_text = (
        f"### Context Overview:\n"
        f"This is the {combined_context}\n"
        f"### Instructions:\n"
        f"Using the provided context, please answer the following question. Your response should:\n"
        f"- Be as clear and concise as possible.\n"
        f"- If the answer is not present in the context, respond with 'I don't know' instead of providing an incorrect answer.\n"
        f"- Make a proper, meaningful sentence for answering.\n\n"
        f"### Question:\n"
        f"{query}\n\n"
        f"### Your Answer:"
    )


    response = llm(input_text, temperature=0.3)
    return response[0]['generated_text'].strip()

# %%
query = "What was the missing dog's name?"
response = generate_rag_response(query, model, tokenizer, index, content_chunks)
print("Generated Response:", response)
# Out:
# Generated Response: The missing dog's name was Benny.
